# %%
import setup
setup.init()

# %%
from ai.tools import list_documents, get_document

# %%
config = {
    "user_id": 2,  # Example user ID

}

# %%
list_documents.invoke(None,config)
# Out:
# {'tags': [], 'metadata': {'user_id': 2}, 'callbacks': None, 'recursion_limit': 25, 'configurable': {'user_id': 2}}
# []

# %%
get_document.invoke({"document_id": 2}, config)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 get_document.invoke({"document_id": 2}, config)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\langchain_core\tools\base.py:599, in BaseTool.invoke(self, input, config, **kwargs)
#     591 @override
#     592 def invoke(
#     593     self,
#    (...)
#     596     **kwargs: Any,
#     597 ) -> Any:
#     598     tool_input, kwargs = _prep_run_args(input, config, **kwargs)
# --> 599     return self.run(tool_input, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\langchain_core\tools\base.py:883, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     881 if error_to_raise:
#     882     run_manager.on_tool_error(error_to_raise)
# --> 883     raise error_to_raise
#     884 output = _format_output(content, artifact, tool_call_id, self.name, status)
#     885 run_manager.on_tool_end(output, color=color, name=self.name, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\langchain_core\tools\base.py:852, in BaseTool.run(self, tool_input, verbose, start_color, color, callbacks, tags, metadata, run_name, run_id, config, tool_call_id, **kwargs)
#     850     if config_param := _get_runnable_config_param(self._run):
#     851         tool_kwargs = tool_kwargs | {config_param: config}
# --> 852     response = context.run(self._run, *tool_args, **tool_kwargs)
#     853 if self.response_format == "content_and_artifact":
#     854     if not isinstance(response, tuple) or len(response) != 2:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\langchain_core\tools\structured.py:93, in StructuredTool._run(self, config, run_manager, *args, **kwargs)
#      91     if config_param := _get_runnable_config_param(self.func):
#      92         kwargs[config_param] = config
# ---> 93     return self.func(*args, **kwargs)
#      94 msg = "StructuredTool does not support sync invocation."
#      95 raise NotImplementedError(msg)
#
# File c:\Users\Soumo\Documents\Projects\AIAgent\src\ai\tools.py:34, in get_document(document_id, config)
#      32 user_id = config.get("user_id")
#      33 if user_id is None:
# ---> 34     raise Exception("Invalid request for the user")
#      36 try:
#      37     qs = Documents.objects.filter(active=True, owner_id=user_id, id=document_id)
#
# Exception: Invalid request for the user
